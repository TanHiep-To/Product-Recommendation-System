# %% [markdown]
# ## Content Based Filtering
# 1. In this recommender system the content of the movie (overview, cast, crew, keyword, tagline etc) is used to find its similarity with other movies. Then the movies that are most likely to be similar are recommended.
#
# 2. We will compute pairwise similarity scores for all movies based on their plot descriptions and recommend movies based on that similarity score. The plot description is given in the overview feature of our dataset. Let's take a look at the data. ..
#
# 3. For any of you who has done even a bit of text processing before knows we need to convert the word vector of each overview. Now we'll compute Term Frequency-Inverse Document Frequency (TF-IDF) vectors for each overview.
#
# Now if you are wondering what is term frequency , it is the relative frequency of a word in a document and is given as (term instances/total instances). Inverse Document Frequency is the relative count of documents containing the term is given as log(number of documents/documents with term) The overall importance of each word to the documents in which they appear is equal to TF * IDF
#
# This will give you a matrix where each column represents a word in the overview vocabulary (all the words that appear in at least one document) and each row represents a movie, as before.This is done to reduce the importance of words that occur frequently in plot overviews and therefore, their significance in computing the final similarity score.
#
# 4. We see that over 20,000 different words were used to describe the 4800 movies in our dataset.
#
# With this matrix in hand, we can now compute a similarity score. There are several candidates for this; such as the euclidean, the Pearson and the cosine similarity scores. There is no right answer to which score is the best. Different scores work well in different scenarios and it is often a good idea to experiment with different metrics.
#
# We will be using the cosine similarity to calculate a numeric quantity that denotes the similarity between two movies. We use the cosine similarity score since it is independent of magnitude and is relatively easy and fast to calculate. Mathematically, it is defined as follows: cos(alpha)

# %%
import os
import sys
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)
from Movie.pre_processing import MovieDataset
from Movie.recommend.content_based_filtering import ContentBasedFiltering

# %%
credits_path = os.path.join(parent_dir, 'data', 'raw', 'tmdb_5000_credits.csv')
movies_path = os.path.join(parent_dir, 'data', 'raw', 'tmdb_5000_movies.csv')

# %%
dataset = MovieDataset(credits_path, movies_path)
dataset.load_data()
dataset.preprocess_data()
processed_data = dataset.data
print("Processed data sample:")
print(processed_data.head())
# Out:
# Starting data loading...
# Starting data preprocessing...
# Processed data sample:
#        id                                           overview  \
# 0   19995  In the 22nd century, a paraplegic Marine is di...
# 1     285  Captain Barbossa, long believed to be dead, ha...
# 2  206647  A cryptic message from Bond’s past sends him o...
# 3   49026  Following the death of District Attorney Harve...
# 4   49529  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  popularity release_date  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...  150.437577   2009-12-10
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...  139.082615   2007-05-19
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...  107.376788   2015-10-26
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  112.312950   2012-07-16
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...   43.926995   2012-03-07
#
#    vote_average  vote_count       budget       revenue  runtime    status  \
# 0           7.2       11800  237000000.0  2.787965e+09    162.0  Released
# 1           6.9        4500  300000000.0  9.610000e+08    169.0  Released
# 2           6.3        4466  245000000.0  8.806746e+08    148.0  Released
# 3           7.6        9106  250000000.0  1.084939e+09    165.0  Released
# 4           6.1        2124  260000000.0  2.841391e+08    132.0  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title           director
# 0                                    Avatar      James Cameron
# 1  Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                   Spectre         Sam Mendes
# 3                     The Dark Knight Rises  Christopher Nolan
# 4                               John Carter     Andrew Stanton

# %%
Content_Based_filtering = ContentBasedFiltering(processed_data)
# Out:
# TF-IDF matrix shape: (4802, 20977)
# Feature names: ['00' '000' '007' '07am' '10' '100' '1000' '101' '108' '10th']
# Cosine similarity matrix shape: (4802, 4802)

# %%
test_movie_title = ['The Dark Knight Rises', 'Inception', 'Interstellar', 'The Matrix', 'Fight Club', 'Forrest Gump', 'The Shawshank Redemption']
recommendations = [Content_Based_filtering.recommend(movie, top_n=10) for movie in test_movie_title]

# %%
print(f"Top 10 movie recommendations based on content for {test_movie_title}:")
for i, rec in enumerate(recommendations):
    print(f"Recommendations for {test_movie_title[i]}:")
    print(rec[['title', 'overview', 'vote_average', 'vote_count']])
# Out:
# Top 10 movie recommendations based on content for ['The Dark Knight Rises', 'Inception', 'Interstellar', 'The Matrix', 'Fight Club', 'Forrest Gump', 'The Shawshank Redemption']:
# Recommendations for The Dark Knight Rises:
#                                         title  \
# 65                            The Dark Knight
# 299                            Batman Forever
# 428                            Batman Returns
# 1359                                   Batman
# 3854  Batman: The Dark Knight Returns, Part 2
# 119                             Batman Begins
# 2507                                Slow Burn
# 9          Batman v Superman: Dawn of Justice
# 1181                                      JFK
# 210                            Batman & Robin
#
#                                                overview  vote_average  \
# 65    Batman raises the stakes in his war on crime. ...           8.2
# 299   The Dark Knight of Gotham City confronts a das...           5.2
# 428   Having defeated the Joker, Batman now faces th...           6.6
# 1359  The Dark Knight of Gotham City begins his war ...           7.0
# 3854  Batman has stopped the reign of terror that Th...           7.9
# 119   Driven by tragedy, billionaire Bruce Wayne ded...           7.5
# 2507  A district attorney (Ray Liotta) is involved i...           5.5
# 9     Fearing the actions of a god-like Super Hero l...           5.7
# 1181  New Orleans District Attorney Jim Garrison dis...           7.5
# 210   Along with crime-fighting partner Robin and ne...           4.2
#
#       vote_count
# 65         12002
# 299         1498
# 428         1673
# 1359        2096
# 3854         419
# 119         7359
# 2507          16
# 9           7004
# 1181         502
# 210         1418
# Recommendations for Inception:
#                                    title  \
# 2897                              Cypher
# 134   Mission: Impossible - Rogue Nation
# 1930                          Stone Cold
# 914                 Central Intelligence
# 1683                     Pitch Perfect 2
# 1248                      At First Sight
# 1512               A History of Violence
# 2389                         Renaissance
# 1803                      Blood and Wine
# 1267                              Duplex
#
#                                                overview  vote_average  \
# 2897  An unsuspecting, disenchanted man finds himsel...           6.7
# 134   Ethan and team take on their most impossible m...           7.1
# 1930  Joe Huff (Brian Bosworth) is a tough, loner co...           5.7
# 914   After he reunites with an old pal through Face...           6.2
# 1683  The Bellas are back, and they are better than ...           6.8
# 1248  A blind man has an operation to regain his sig...           5.9
# 1512  An average family is thrust into the spotlight...           6.9
# 2389  To find Ilona and unlock the secrets of her di...           6.7
# 1803  A man who has failed as a father and husband c...           5.5
# 1267  When a young couple buys their dream home, the...           5.9
#
#       vote_count
# 2897         192
# 134         3224
# 1930          34
# 914         1650
# 1683        1940
# 1248          48
# 1512         832
# 2389          77
# 1803          34
# 1267         482
# Recommendations for Interstellar:
#                                   title  \
# 1709       Space Pirate Captain Harlock
# 300                   Starship Troopers
# 4353                  The Green Inferno
# 220                          Prometheus
# 2260                    All Good Things
# 268                       Stuart Little
# 1352                            Gattaca
# 4176  Battle for the Planet of the Apes
# 2648                     Winnie Mandela
# 634                          The Matrix
#
#                                                overview  vote_average  \
# 1709  Space Pirate Captain Harlock and his fearless ...           6.5
# 300   Set in the future, the story follows a young s...           6.7
# 4353  A group of student activists travel from New Y...           5.0
# 220   A team of explorers discover a clue to the ori...           6.3
# 2260  Newly-discovered facts, court records and spec...           5.9
# 268   The adventures of a heroic and debonair stalwa...           5.8
# 1352  Science fiction drama about a future society i...           7.5
# 4176  The fifth and final episode in the Planet of t...           5.5
# 2648  A drama that chronicles the life of Winnie Man...           5.2
# 634   Set in the 22nd century, The Matrix tells the ...           7.9
#
#       vote_count
# 1709         356
# 300         1560
# 4353         349
# 220         5080
# 2260         286
# 268          959
# 1352        1808
# 4176         215
# 2648           5
# 634         8907
# Recommendations for The Matrix:
#                       title  \
# 1281                Hackers
# 2996               Commando
# 2088                  Pulse
# 1341   The Inhabited Island
# 333           Transcendence
# 0                    Avatar
# 261   Live Free or Die Hard
# 775               Supernova
# 125     The Matrix Reloaded
# 2614        The Love Letter
#
#                                                overview  vote_average  \
# 1281  Along with his new friends, a teenager who was...           6.2
# 2996  John Matrix, the former leader of a special co...           6.4
# 2088  When their computer hacker friend accidentally...           5.0
# 1341  On the threshold of 22nd century, furrowing th...           5.3
# 333   Two leading computer scientists work toward th...           5.9
# 0     In the 22nd century, a paraplegic Marine is di...           7.2
# 261   John McClane is back and badder than ever, and...           6.4
# 775   Set in the 22nd century, when a battered salva...           4.9
# 125   Six months after the events depicted in The Ma...           6.7
# 2614  20th century computer games designer Scott exc...           4.7
#
#       vote_count
# 1281         398
# 2996         742
# 2088         150
# 1341          23
# 333         2295
# 0          11800
# 261         2089
# 775          109
# 125         3443
# 2614           3
# Recommendations for Fight Club:
#                       title  \
# 3619                    UHF
# 2828              Project X
# 2585        The Hurt Locker
# 2344            Raging Bull
# 2023             The Animal
# 1414    Blast from the Past
# 4044             Go for It!
# 3515           Freaky Deaky
# 4045  Dancer, Texas Pop. 81
# 4759  This Is Martin Bonner
#
#                                                overview  vote_average  \
# 3619  The eccentric new manager of a UHF television ...           6.7
# 2828  Three high school seniors throw a party to mak...           6.5
# 2585  Forced to play a dangerous game of cat-and-mou...           7.2
# 2344  When Jake LaMotta steps into a boxing ring and...           7.7
# 2023  When loser Marvin Mange is involved in a horri...           4.6
# 1414  Following a bomb scare in the 1960s that locke...           6.3
# 4044  Carmen is a good student with a bad attitude w...           4.6
# 3515  Set in 1974, a pair of '60s radicals rely on t...           4.9
# 4045  Four guys, best friends, have grown up togethe...          10.0
# 4759  Two men, at opposite ends of the social spectr...           6.6
#
#       vote_count
# 3619          89
# 2828        1564
# 2585        1840
# 2344         938
# 2023         304
# 1414         245
# 4044           5
# 3515          18
# 4045           1
# 4759           4
# Recommendations for Forrest Gump:
#                             title  \
# 2686         An American Haunting
# 2904           Heaven is for Real
# 4287                      Niagara
# 725                The Shaggy Dog
# 2760                         Room
# 124                        Frozen
# 1098  Love in the Time of Cholera
# 3649                Lovely, Still
# 1871           Mr. Bean's Holiday
# 4640  I Married a Strange Person!
#
#                                                overview  vote_average  \
# 2686  Based on the true events of the only case in U...           5.3
# 2904  Heaven is for Real recounts the true story of ...           6.0
# 4287  Rose Loomis and her older, gloomier husband, G...           6.7
# 725   The tale of a workaholic dad-turned-dog who fi...           4.5
# 2760  Jack is a young boy of 5 years old who has liv...           8.1
# 124   Young princess Anna of Arendelle dreams about ...           7.3
# 1098  In Colombia just after the Great War, an old m...           6.4
# 3649  A holiday fable that tells the story of an eld...           6.2
# 1871  Mr. Bean wins a trip to Cannes where he unwitt...           6.1
# 4640  A newlywed develops a strange lump on his neck...           7.5
#
#       vote_count
# 2686         142
# 2904         229
# 4287          79
# 725          137
# 2760        2757
# 124         5295
# 1098          81
# 3649          13
# 1871         663
# 4640          12
# Recommendations for The Shawshank Redemption:
#                        title  \
# 4531             Civil Brand
# 3785                  Prison
# 609              Escape Plan
# 2868                Fortress
# 4726            Penitentiary
# 1779  The 40 Year Old Virgin
# 2667        Fatal Attraction
# 3871       A Christmas Story
# 434         The Longest Yard
# 42               Toy Story 3
#
#                                                overview  vote_average  \
# 4531  Forced to work under slave-like conditions in ...           5.3
# 3785  After Charles Forsyth was sent to the electric...           6.7
# 609   Ray Breslin is the world's foremost authority ...           6.7
# 2868  A futuristic prison movie. Protagonist and wif...           5.7
# 4726  A hitchhiker named Martel Gordone gets in a fi...           4.9
# 1779  Andy Stitzer has a pleasant life with a nice a...           6.2
# 2667  A married man's one night stand comes back to ...           6.6
# 3871  The comic mishaps and adventures of a young bo...           7.4
# 434   Pro quarter-back, Paul Crewe and former colleg...           6.2
# 42    Woody, Buzz, and the rest of Andy's toys haven...           7.6
#
#       vote_count
# 4531           4
# 3785          27
# 609         1659
# 2868         168
# 4726           8
# 1779        1983
# 2667         291
# 3871         344
# 434          785
# 42          4597
